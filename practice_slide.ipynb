# %%
import pandas as pd
df=pd.DataFrame()
df['Name']=['a','b','c']
df['Gender']=['m','f','m']
df['age']=[20,10,12]
df
# Out:
#   Name Gender  age
# 0    a      m   20
# 1    b      f   10
# 2    c      m   12

# %%
df.iloc[1,2]
df.iloc[1:3,2]
# Out:
# 1    10
# 2    12
# Name: age, dtype: int64

# %%
df[df['Gender']=='m']
# Out:
#   Name Gender  age
# 0    a      m   20
# 2    c      m   12

# %%
df[df['age']>=5]
# Out:
#   Name Gender  age
# 0    a      m   20
# 1    b      f   10
# 2    c      m   12

# %%
df[df['age']>=11]
# Out:
#   Name Gender  age
# 0    a      m   20
# 2    c      m   12

# %%
df=df.replace('f','female')
df=df.replace('m','male')
df
# Out:
#   Name  Gender  age
# 0    a    male   20
# 1    b  female   10
# 2    c    male   12

# %%
df=df.rename(columns={'age':'umar'})
df=df.rename(columns={'Name':'naam'})
df=df.rename(columns={'stree_purush':'stree/purush'})
df
# Out:
#   naam stree/purush  umar
# 0    a         male    20
# 1    b       female    10
# 2    c         male    12
